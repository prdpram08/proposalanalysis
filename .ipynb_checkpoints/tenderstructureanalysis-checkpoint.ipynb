# %%
import sys
stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf-8')
sys.stdout = stdout

# %%
# %matplotlib inline
# import sys
# reload(sys)
# sys.setdefaultencoding('utf8')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy.stats as stats
import plotly
plotly.tools.set_credentials_file(username='prdpram08', api_key='vahwmX6mq11V2fHIeQi6')
import plotly.plotly as py
from plotly.graph_objs import *
import string
import plotly.graph_objs as go
import cufflinks as cf
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LassoLarsCV
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 500
#df= pd.read_excel(open('C:\Users\pradeep.ram\Downloads\propsalanalysis\pr.xlsx','rb'), sheetname='Sheet1', encoding='ISO-8859-1')
#df= pd.read_excel(open('C:\Users\pradeep.ram\Downloads\propsalanalysis\pr.xlsx','rb'), sheetname='Sheet1', encoding='UTF-8')
df= pd.read_excel(open('data.xlsx','rb'), sheetname='5june')
df.head()
# Out:
#                                                                                                                                                                                                            Africa
# 0                           1. Burundi- Consultancy Services For Carrying Out Detailed Studies Of The Projects For The Construction Of Drinking Water Supply Pipes And Latrine Blocks With Two Drainable Latrines
# 1                                                                                                       2. Burundi- Development Of The Cartographic Organization Of Solidarity Economic Organizations In Burundi.
# 2  3. Ghana- Digital Skills For Ghana. Under The Ifc Advisory Services Project 602771, Skills In Africa, Ifc Is Aiming To Develop A White Paper Focusing On Digital Skills For Africa. Specific Emphasis On Ghana
# ...

# %%
df2= pd.read_excel(open('data.xlsx','rb'), sheetname='St', index_col=[0,1])
df2.head(20)
df2.fillna(0,inplace=True)

# %%
df2 = df2.set_index([df1['Title'].eq('Project Title').cumsum(), 'Title'])['Description'].unstack().reset_index(drop=True)
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-35-f1b25f6a1b49> in <module>()
# ----> 1 df2 = df2.set_index([df1['Title'].eq('Project Title').cumsum(), 'Title'])['Description'].unstack().reset_index(drop=True)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexes\multi.pyc in __getitem__(self, key)
#    1365             retval = []
#    1366             for lev, lab in zip(self.levels, self.labels):
# -> 1367                 if lab[key] == -1:
#    1368                     retval.append(np.nan)
#    1369                 else:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# df1 = df2.iloc[:,0:2]
df1=df2.index

# %%
df1
# Out:
# MultiIndex(levels=[[u'100.India - 17k67c001/cctv Camera With Accessories For Ships', u'101.India - Gis Mapping Of Land Property Through Modern Gis Technologies Like Dgps And Ets And Web Gis Software Development', u'102.India - Supply, Installation, Testing And Commissioning Of 10 Mtr Mini Mast Lights With 100w X 4 Nos. Led Floodlights And 5 Years Warranty At Kallara Grama Panchayath, Vaikom Lac, Kottayam', u'103.India - Supply, Installation, Testing And Commissioning Of 7 Nos. Of 10 Mtr High Mast Lights With 180 W X 6 Nos. Led Flood Lights And 5 Years Warranty At Various Locations In Thalayolaparamb Grama Panchayath,', u'104.India - Relevant Experience/insights In The Field Of Professional Electronics For Participation In Transfer Of Technology (tot) And Licensing Of Tetra Based Products/ Technologies Developed By C-dac.', u'105.India - Adobe Acrobat Pro Dc For Mac', u'106.India - Alappuzha Municipality Amrut -saap 2015-16, 2016-17, 2017-18 Green Space And Parks-development Of Valiya
# ...

# %%
df2.dropna(how='all',inplace=True) 
df2.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []

# %%
df1.columns = ['Title', 'Description']
df1.head(100)
# Out:
#                                                                                                                                                                                                                                                   Title  \
# TI Ref. No.                                                                                                                                                                                          434921752               Notice Type :Tender Notice
# Bidding Type                                                                                                                                                                                                               Domestic Competitive Bidding
# ...

# %%
df1.head()
# Out:
#                                                                                                              Title  \
# 0  29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi
# 1                                                                                                      TI Ref. No.
# 2                                                                                                     Bidding Type
# 3                                                                                                 Project Location
# 4                                                                                                      Description
#
#                                                                                                                     Description
# 0                                                                                                                           NaN
# ...

# %%
df1.Title = df1.Title.fillna(method='ffill')
df1.Description = df1.Description.replace(np.nan, 'project', regex=True)

# %%
df1.head(200)
# Out:
#                                                                                                                                                                                                                            Title  \
# 0                                                                                                                29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi
# 1                                                                                                                                                                                                                    TI Ref. No.
# 2                                                                                                                                                                                                                   Bidding Type
# ...

# %%
df1.Description=df1.Description.astype(str)
df1.Title=df1.Title.astype(str)

# %%
df1.groupby(['Title'],sort=False,as_index=False)["Description"].agg(lambda x :' '.join(x))
# Out:
#                                                                                                                                                                                                                            Title  \
# 0                                                                                                                29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi
# 1                                                                                                                                                                                                                    TI Ref. No.
# 2                                                                                                                                                                                                                   Bidding Type
# ...

# %%
d=df1.groupby(['Title'],sort=False,group_keys=False,as_index=True)['Description'].apply(lambda x: ",".join(x))

# %%
d.head()
# Out:
# Title
# 29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                project
# ...

# %%
df1.groupby(['Title'],as_index=True).agg(lambda x :' '.join(x))
# Out:
#                                                                                                                                                                                                                                    Description
# Title
# 100.India - 17k67c001/cctv Camera With Accessories For Ships                                                                                                                                                                 Title Description
# 101.India - Gis Mapping Of Land Property Through Modern Gis Technologies Like Dgps And Ets And Web Gis Software Development                                                                                                  Title Description
# 102.India - Supply, Installation, Testing And Commissioning Of 10 Mtr Mini Mast Lights With 100w X 4 Nos. Led Floodlights And 5 Years Warranty At Kallara Grama Panchayath, Vaikom Lac, Kottayam                             Title Description
# ...

# %%
df1.groupby(['Title'])['Description'].apply(lambda x: ','.join(x)).reset_index()
# df1.groupby(['Title'])['Description'].apply(','.join).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-92271f26af3d> in <module>()
# ----> 1 df1.groupby(['Title'])['Description'].apply(lambda x: ','.join(x)).reset_index()
#       2 # df1.groupby(['Title'])['Description'].apply(','.join).reset_index()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %%
df1

# %%
# df1.dropna(subset=["Title"],inplace=True) 
# df1.head()
# Out:
#                                                                                                              Title  \
# 0  29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi
# 1                                                                                                      TI Ref. No.
# 2                                                                                                     Bidding Type
# 3                                                                                                 Project Location
# 4                                                                                                      Description
#
#                                                                                                                     Description
# 0                                                                                                                           NaN
# ...

# %%
# df1 = df1.replace(np.nan, 'project', regex=True)
# df1.head()
# Out:
#                                                                                                              Title  \
# 0  29.India - Guntakal Division:- Collection Of Site Details And Preparation And Supply Of Bridge Completion Drawi
# 1                                                                                                      TI Ref. No.
# 2                                                                                                     Bidding Type
# 3                                                                                                 Project Location
# 4                                                                                                      Description
#
#                                                                                                                     Description
# 0                                                                                                                       project
# ...

# %%
h=['Bidding Type','Client Address','Deadline','Description','Estimated Cost','Financier','Latest Update','Organisation','Project Location','Related Documents :','TI Ref. No.','Tender Notice No.']
for index, row in df1.iterrows():
     if (row["Description"]=="project") & (row["Title"] not in h):
        row["Description"]=row["Title"]
        row["Title"]="Project Title"
df1
# Out:
#                     Title  \
# 0           Project Title
# 1             TI Ref. No.
# 2            Bidding Type
# 3        Project Location
# 4             Description
# 7            Organisation
# 8          Client Address
# 9       Tender Notice No.
# 10               Deadline
# 11    Related Documents :
# 15          Project Title
# 16            TI Ref. No.
# 17           Bidding Type
# 18       Project Location
# 19            Description
# 21           Organisation
# 22         Client Address
# 25      Tender Notice No.
# 26               Deadline
# 27    Related Documents :
# 31          Project Title
# 32            TI Ref. No.
# 33           Bidding Type
# 34       Project Location
# 35            Description
# 55           Organisation
# 56         Client Address
# 57      Tender Notice No.
# 58          Latest Update
# 59               Deadline
# 60    Related Documents :
# 64          Project Title
# 65            TI Ref. No.
# 66           Bidding Type
# ...

# %%
df1.Title.unique()
# Out:
# array(['Project Title', u'TI Ref. No.', u'Bidding Type',
#        u'Project Location', u'Description', u'Organisation',
#        u'Client Address', u'Tender Notice No.', u'Deadline',
#        u'Related Documents :', u'Latest Update', u'Estimated Cost',
#        u'Financier'], dtype=object)

# %%
df1.Title.value_counts()
# Out:
# Bidding Type           197
# Description            197
# Organisation           197
# Deadline               197
# TI Ref. No.            197
# Project Title          197
# Client Address         197
# Project Location       197
# Related Documents :    197
# Tender Notice No.      188
# Estimated Cost          96
# Latest Update           19
# Financier                1
# Name: Title, dtype: int64

# %%
df1 = df1.set_index([df1['Title'].eq('Project Title').cumsum(), 'Title'])['Description'].unstack().reset_index(drop=True)
df1
# Out:
# Title                                      Bidding Type  \
# 0                          Domestic Competitive Bidding
# 1                          Domestic Competitive Bidding
# 2                          Domestic Competitive Bidding
# 3                          Domestic Competitive Bidding
# 4                          Domestic Competitive Bidding
# 5                          Domestic Competitive Bidding
# 6                          Domestic Competitive Bidding
# 7                          Domestic Competitive Bidding
# 8                          Domestic Competitive Bidding
# 9                          Domestic Competitive Bidding
# 10                         Domestic Competitive Bidding
# 11                         Domestic Competitive Bidding
# 12                         Domestic Competitive Bidding
# 13                         Domestic Competitive Bidding
# 14                         Domestic Competitive Bidding
# 15                         Domestic Competitive Bidding
# ...

# %%
df1.dtypes
# Out:
# Title
# Bidding Type           object
# Client Address         object
# Deadline               object
# Description            object
# Estimated Cost         object
# Financier              object
# Latest Update          object
# Organisation           object
# Project Location       object
# Project Title          object
# Related Documents :    object
# TI Ref. No.            object
# Tender Notice No.      object
# dtype: object
